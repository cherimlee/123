# %%
txt1 = 'a tale that was not right'
#

# %%
txt1[3:6]   #slicing
# Out:
# 'ale'

# %%
txt1[-9:-6]
# Out:
# 'not'

# %%
txt1.upper()
# Out:
# 'A TALE THAT WAS NOT RIGHT'

# %%
txt1.lower()
# Out:
# 'a tale that was not right'

# %%
txt1.count('o')
# Out:
# 1

# %%
txt1.find('o')
# Out:
# 17

# %%
txt1.index('o')
# Out:
# 17

# %%
len(txt1)
# Out:
# 25

# %%
txt1.split()
# Out:
# ['a', 'tale', 'that', 'was', 'not', 'right']

# %%
txt1.split('/')
# Out:
# ['a tale that was not right']

# %%
txt1.replace('tale', 'story')
# Out:
# 'a story that was not right'

# %%
'right' in txt1 # right가 있는지 확인
# Out:
# True

# %%
# 군집형 데이터타입 - index(주소) []

# string - 문자열, 원소의 수정, 삭제, 추가가 안 됨
# list - 리스트, 원소의 수정, 삭제, 추가가 자유로움, 모든 데이터를 담을 수 있음
# set - 집합, 중복 데이터를 허용하지 않는다, 순서X(index가 없음)
# tuple - 원소의 수정, 삭제, 추가가 안 됨, 고정된 값을 표현할 때 사용, 데이터를 묶는 보조적 용도
# dictionary - 사전, 단어: 뜻 -> key:value -> key가 인덱스 역할

# %%
마우스 컨트롤 시프트 마이너스 -> 셀 나누기

# %%
#List

sol = ["태양","수성","금성","지구","화성","목성","지구"]
sol1 = ["토성","천왕성","해왕성"]
planet = '지구'

# %%
sol[1:3]
# Out:
# ['수성', '금성']

# %%
# 위치 인덱스 출력
sol.index('지구')
# Out:
# 3

# %%
sol[4] = '해왕성'
print(sol)
# Out:
# ['태양', '수성', '금성', '지구', '해왕성', '목성', '지구']

# %%
# 맨 끝에 토성 삽입
sol.append('토성')
sol
# Out:
# ['태양', '수성', '금성', '지구', '해왕성', '목성', '지구', '토성', '토성']

# %%
# 특정 자리에 삽입
sol.insert(1,'명왕성')
sol
# Out:
# ['명왕성']

# %%
# 맨 끝 요소를 삭제하고 리턴
sol.pop()
sol
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/2829082997.py in <module>
#       1 # 맨 끝 요소를 삭제하고 리턴
# ----> 2 sol.pop()
#       3 sol
#
# IndexError: pop from empty list

# %%
# 금성을 제거 
sol.remove('금성')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/649634297.py in <module>
#       1 # 금성을 제거
# ----> 2 sol.remove('금성')
#
# ValueError: list.remove(x): x not in list

# %%
sol.pop(2)
sol
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/1278809381.py in <module>
# ----> 1 sol.pop(2)
#       2 sol
#
# IndexError: pop index out of range

# %%
del sol[1:2]
sol
# Out:
# ['태양']

# %%
sol + sol1
# Out:
# ['태양', '토성', '천왕성', '해왕성']

# %%
#내림차순 정렬
sorted[sol, reverse = True]
# Out:
#   File "C:\Users\bitcamp\AppData\Local\Temp/ipykernel_6672/1797887451.py", line 2
#     sorted[sol, reverse = True]
#                         ^
# SyntaxError: invalid syntax

# %%
#오름차순 정렬
sorted(sol)
# Out:
# ['태양']

# %%
#시퀀스가 있는지 확인 - in 사용
'만리장성' in sol
# Out:
# False

# %%
sol * 3
# Out:
# ['명왕성', '명왕성', '명왕성']

# %%
len(sol)
# Out:
# 1

# %%
sol.count('지구')
# Out:
# 0

# %%
# 모든 원소 지우기
sol.clear()
sol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/3569474593.py in <module>
#       1 # 모든 원소 지우기
# ----> 2 sol.clear()
#       3 sol
#
# NameError: name 'sol' is not defined

# %%
# sol 리스트 삭제
del sol
sol
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/3426276002.py in <module>
#       1 # sol 리스트 삭제
#       2 del sol
# ----> 3 sol
#
# NameError: name 'sol' is not defined

# %%
#Tuple - 원소 수정 불가

myTuple = ('tuple',(1,2,3), [4,5,6,7,8],'7','8','9')

# %%
print(myTuple)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6672/647953058.py in <module>
# ----> 1 print(myTuple)
#
# NameError: name 'myTuple' is not defined

# %%
# Set = 중복 데이터가 없다, 순서가 없으므로 인덱스가 없다. 집합연산
# 합집합, 교집합

A = {1,2,3,4,5,6}
B = {1,2,3,7,8,9}
C = {1,2,3}
